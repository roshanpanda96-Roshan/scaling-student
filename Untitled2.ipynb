# %% [markdown]
# <a href="https://colab.research.google.com/github/roshanpanda96-Roshan/scaling-student/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path="/student.csv"
df=pd.read_csv(path)
print(df)
# Out:
#     Stud_Id       Name  Age  RollNo Section
# 0         1     Roshan   21      10       A
# 1         2    Shibang   20      11       B
# 2         3  Priyanshu   20      12       C
# 3         4     Rishav   20      13       A
# 4         5  shreyansh   21      14       B
# 5         6      Rahul   22      15       C
# 6         7        Roy   21      16       B
# 7         8     Ranjan   21      17       B
# 8         9      Mohan   20      18       A
# 9        10      Sohan   21      19       D
# 10       11     Tushar   21      20       A
# 11       12   Divyansh   22      21       A
# 12       13     shreya   21      22       B
# 13       14      Amrit   21      23       B
# 14       15       Amit   21      24       B
# 15       16      Mihir   21      25       A
# 16       17     Swayam   21      26       D
# 17       18   Sankalpa   21      27       C
# 18       19      Suraj   21      28       B
# 19       20      Raman   21      29       A
